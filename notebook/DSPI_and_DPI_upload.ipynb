# %%
import pandas as pd
import numpy as np

# %%
import sys
import os 

sys.path.append(os.path.abspath('/Users/anhnguyendo/Documents/Python machine learning/US CPI project/us-consumer-spending-inflation/scripts'))

from fetch_fred_data import fetch_fred_series, fetch_and_save_series

os.makedirs("data/raw", exist_ok=True)

series_to_fetch = ["DSPI"]

for series in series_to_fetch:
    fetch_and_save_series(series_to_fetch)
# Out:
# Fetching series: DSPI
# Status Code: 200
# ...
